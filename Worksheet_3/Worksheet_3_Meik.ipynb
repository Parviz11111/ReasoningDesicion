# %%
import numpy as np

# Set the dimensions
dims = [2, 5, 10]

# Generate random vectors for each dimension
for dim in dims:
    mean = np.zeros(dim)
    cov = np.eye(dim)
    samples = np.random.multivariate_normal(mean, cov, size=10)
    print(f"Random vectors of dimension {dim}:\n{samples}\n")
# Out:
# Random vectors of dimension 2:
# [[ 0.48375887  0.19286017]
#  [-0.06019682  1.704668  ]
#  [ 0.46175081  0.54611242]
#  [-0.15307238  0.52734102]
#  [-0.90827996  0.54120691]
#  [-0.46832169 -0.36069761]
#  [ 0.06666389 -1.04998137]
#  [ 0.07705843  0.21621193]
#  [ 1.01800595  0.56919401]
#  [-0.70284126  0.01332748]]
#
# Random vectors of dimension 5:
# [[ 0.57681258  0.32623828  1.04332063  1.60174732  0.47738037]
#  [-0.76229867 -0.72199735 -1.11027119 -1.77277453  0.99980667]
#  [-2.03139414 -0.49794855  1.29693647 -0.10703579  1.18831141]
#  [ 0.10474278  0.21037423  0.03983577 -0.3808595  -1.03448881]
#  [-1.04893317 -0.22914066  0.22923184  1.98929866  0.7355375 ]
#  [-0.33012637  0.95820328  1.14505466 -0.04134122 -0.52253518]
#  [ 1.76676034 -0.50485106  1.23714252  0.29956394  0.33595366]
#  [ 0.46624423 -1.15309127 -0.13248757 -0.7945001  -0.65016607]
#  [-1.31054815 -1.53684245 -0.91835822 -0.6583997   0.93195162]
#  [ 1.25278624  0.74609521 -0.80097331  1.14376367  0.11606556]]
#
# Random vectors of dimension 10:
# [[-0.54727356 -0.29092241 -0.27519205  2.29540758  0.04717876 -1.27366229
#    0.20376072 -0.81387937  0.27547007  0.78446896]
#  [ 2.04525998  0.41796534 -1.48822102 -1.14151796 -0.39405074 -0.55441947
#   -0.94992305  0.79618314 -0.26918866 -0.80333611]
#  [ 0.78863312 -0.15901652 -0.07578521 -0.86357782  0.07119802  0.73807398
#    0.32303146 -0.1514912   0.85541483 -0.10111103]
#  [ 0.57450683  0.05842074  1.77530507 -1.52126648  0.59435664 -0.81776196
#   -0.70417473 -0.43796975  0.9853862   0.25867982]
#  [ 2.06348747 -0.20535764  0.76821747  0.22538186  0.72728082  1.63617098
#   -1.30021884  0.86121028 -0.55916414 -0.58157529]
#  [-0.39990989  0.10902874 -0.46339249 -0.48974275  0.25826168 -0.41463428
#   -1.00953486  0.06867128 -0.27871366 -0.95201003]
#  [-1.40095895 -0.53980716  1.32935289 -0.94583144  0.02179023  0.31560799
#    0.3957068   1.04060502 -1.0254209  -0.93367441]
#  [ 1.96946088 -0.18991838  1.46359362 -1.14649253  0.55328437  0.05965276
#   -1.29943166  0.720013   -1.42695124 -0.25816947]
#  [-0.7823261  -0.09800566 -0.93539306 -1.58918886 -0.07848381  0.5829242
#   -1.48105346  0.06921692 -0.25635584  0.64740159]
#  [-1.53532535 -1.01992169 -0.91194095 -0.14658584  0.53153944  1.39052449
#   -2.15179649  0.55318231 -0.95801376 -0.07618193]]

# %%
# Set the dimension and sample size
dim = 5
size = 100

# Generate a sample set of random vectors
mean = np.zeros(dim)
cov = np.eye(dim)
samples = np.random.multivariate_normal(mean, cov, size=size)

# Estimate the mean and covariance matrix of the underlying distribution
sample_mean = np.mean(samples, axis=0)
sample_cov = np.cov(samples.T)

print(f"Sample mean:\n{sample_mean}\n")
print(f"Sample covariance matrix:\n{sample_cov}\n")
# Out:
# Sample mean:
# [ 0.01713729  0.06984888 -0.00047806  0.09629751  0.06229759]
#
# Sample covariance matrix:
# [[ 0.90928467 -0.09553534 -0.14809783 -0.10272637  0.01952593]
#  [-0.09553534  0.83603128  0.04362074 -0.07072168 -0.13041925]
#  [-0.14809783  0.04362074  0.88476586  0.03470913 -0.06666867]
#  [-0.10272637 -0.07072168  0.03470913  1.18552735 -0.1315843 ]
#  [ 0.01952593 -0.13041925 -0.06666867 -0.1315843   1.01261007]]

# %%
import numpy as np

# Set the dimension, mean vector, and covariance matrix
dim = 3
mean = [1, 2, 3]
cov = [[2, 1, 0], [1, 2, 1], [0, 1, 2]]

# Generate a sample set of random vectors
samples = np.random.multivariate_normal(mean, cov, size=10)

print(f"Random vectors with mean vector {mean} and covariance matrix:\n{cov}\n")
print(f"{samples}\n")
# Out:
# Random vectors with mean vector [1, 2, 3] and covariance matrix:
# [[2, 1, 0], [1, 2, 1], [0, 1, 2]]
#
# [[ 5.07171532  3.63681334  0.87509785]
#  [ 0.4267589   2.23133305  3.9387654 ]
#  [-0.6744814  -0.03312096  4.02261598]
#  [ 1.36203006  2.80130789  2.42271173]
#  [ 0.04477937  2.4110378   3.16808557]
#  [ 0.21545939  1.50806649  3.26506816]
#  [ 3.07910254  3.26118868  2.26527829]
#  [ 1.7080278   0.73295556  0.91051905]
#  [ 0.22354359  1.92563869  3.2053251 ]
#  [ 0.81623839  1.55614567  1.76224535]]
